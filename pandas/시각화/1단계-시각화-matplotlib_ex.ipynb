# %% [markdown]
# # ✅ **Matplotlib 기본 차트 종류**
#
# | 차트 종류 | 함수(메서드) | 설명 |
# |-----------|-------------|------|
# | 라인 차트  | `lineplot()` | 연속된 데이터를 라인으로 표현 |
# | 산점도     | `scatter()` | 데이터를 점으로 표시하여 분포 표현 |
# | 막대 차트  | `bar()` / `barh()` | 데이터의 크기를 막대로 비교 |
# | 히스토그램 | `hist()` | 데이터의 빈도 및 분포 표현 |
# | 파이 차트  | `pie()` | 데이터의 구성 비율 표현 |
# | 박스 플롯  | `boxplot()` | 데이터 분포 및 이상치 표현 |
#
# ---

# %% [markdown]
# # ✅ **Matplotlib 주요 옵션**
#
# | 옵션 | 설명 | 예시 |
# |------|------|------|
# | `figsize` | 차트의 크기 지정 | `plt.figure(figsize=(10,6))` |
# | `title` | 차트의 제목 설정 | `plt.title('Title')` |
# | `xlabel`, `ylabel` | x축/y축 레이블 설정 | `plt.xlabel('평균%')` |
# | `legend` | 범례 표시 및 위치 설정 | `plt.legend(loc='best')` |
# | `grid` | 격자선 표시 여부 | `plt.grid(True)` |
# | `xlim`, `ylim` | x축/y축 범위 지정 | `plt.xlim(0, 10)` |
# | `xticks`, `yticks` | 축 눈금 설정 | `plt.xticks(rotation=45)` |
# | `color` | 선이나 점 등의 색상 | `color='blue'` |
#
# ---

# %% [markdown]
# | 옵션 | 설명 |
# |---|---|
# | `plt.figure(figsize=(10, 6))` | 차트의 크기 조정 |
# | `plt.plot(x, y, label='...')` | 라인 차트 그리기 및 범례 이름 설정 |
# | `color`, `linestyle`, `marker` | 선의 색상, 선 스타일, 마커(점) 스타일 설정 |
# | `plt.title()` | 차트 제목 |
# | `plt.xlabel()`, `plt.ylabel()` | x축과 y축 라벨 |
# | `plt.legend()` | 범례 위치 설정 |
# | `plt.grid()` | 격자 표시 |
# | `plt.xlim()`, `plt.ylim()` | x축 및 y축의 범위 설정 |
#
# ---

# %% [markdown]
# # ✅ **차트별 Matplotlib 예시 코드**
#
# ## ① 라인 차트 (`plot`)

# %% [markdown]
# | 옵션 (`loc`) | 위치                  |
# |------------|----------------------|
# | `'best'`   | 최적의 위치 (기본값)     |
# | `'upper right'` | 우측 상단             |
# | `'upper left'` | 좌측 상단             |
# | `'lower right'` | 우측 하단             |
# | `'lower left'` | 좌측 하단             |
# | `'right'`   | 우측                 |
# | `'center'`  | 정중앙                 |
#
# ---

# %%
import matplotlib.pyplot as plt
import numpy as np

# 데이터 생성
x = np.linspace(0, 10, 100)
y = np.sin(x)

x, y
# Out:
# (array([ 0.        ,  0.1010101 ,  0.2020202 ,  0.3030303 ,  0.4040404 ,
#          0.50505051,  0.60606061,  0.70707071,  0.80808081,  0.90909091,
#          1.01010101,  1.11111111,  1.21212121,  1.31313131,  1.41414141,
#          1.51515152,  1.61616162,  1.71717172,  1.81818182,  1.91919192,
#          2.02020202,  2.12121212,  2.22222222,  2.32323232,  2.42424242,
#          2.52525253,  2.62626263,  2.72727273,  2.82828283,  2.92929293,
#          3.03030303,  3.13131313,  3.23232323,  3.33333333,  3.43434343,
#          3.53535354,  3.63636364,  3.73737374,  3.83838384,  3.93939394,
#          4.04040404,  4.14141414,  4.24242424,  4.34343434,  4.44444444,
#          4.54545455,  4.64646465,  4.74747475,  4.84848485,  4.94949495,
#          5.05050505,  5.15151515,  5.25252525,  5.35353535,  5.45454545,
#          5.55555556,  5.65656566,  5.75757576,  5.85858586,  5.95959596,
#          6.06060606,  6.16161616,  6.26262626,  6.36363636,  6.46464646,
# ...

# %%
plt.figure(figsize=(6, 6))  ## 전체 크기(화면)
plt.plot(x, y, color="red")  ## 데이터 입력 , color 설정
plt.title("Line Chart Example")  ## Title
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.show()

# %% [markdown]
# | 옵션                          | 설명                                 | 코드 내 예시                        |
# |-------------------------------|--------------------------------------|-----------------------------------|
# | **`plt.figure(figsize=(10, 6))`** | 차트의 전체 크기 설정 (가로 10, 세로 6) | `plt.figure(figsize=(10, 6))`    |
# | **`plt.plot()`**              | 라인 차트를 그리는 기본 함수          | `plt.plot(x, y1)`                |
# | `color`                       | 선의 색상 지정                       | `color='blue'`, `color='red'`    |
# | `linestyle`                   | 선의 스타일 설정                     | 실선:`'-'`, 점선:`'--'`          |
# | `marker`                      | 데이터 포인트 마커 모양 설정          | 원형:`'o'`, x형:`'x'`            |
# | **`plt.title()`**             | 차트의 제목 설정                     | `plt.title('Two Line Plots: sin(x) and cos(x)')` |
# | **`plt.xlabel()` / `plt.ylabel()`** | x축, y축의 라벨 설정             | `plt.xlabel('X-axis')`           |
# | **`plt.xlim()` / `plt.ylim()`** | x축, y축 범위 지정                 | `plt.xlim(0,10)`                 |
# | **`plt.legend(loc='upper right')`** | 범례 표시 및 위치 설정            | `plt.legend(loc='upper right')`  |
# | **`plt.grid(True)`**          | 격자 표시                            | `plt.grid(True)`                 |

# %%
import matplotlib.pyplot as plt
import numpy as np

# 데이터 생성
x = np.linspace(0, 10, 100)
y1 = np.sin(x)
y2 = np.cos(x)

# 차트 그리기
plt.figure(figsize=(10, 6))
plt.plot(x, y1, color="blue", label="sin(x)")
plt.plot(x, y2, color="red", label="cos(x)")

# 옵션 설정
plt.title("Two Line Plots: sin(x) and cos(x)")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.legend(loc="upper right")
plt.grid(True)

# 표시
plt.show()

# %% [markdown]
# | 옵션                          | 설명                                 | 코드 내 예시                        |
# |-------------------------------|--------------------------------------|-----------------------------------|
# | **`plt.figure(figsize=(10, 6))`** | 차트 전체 크기 설정 (가로 10, 세로 6)   | `plt.figure(figsize=(10, 6))`    |
# | **`plt.plot()`**              | 라인 차트를 그리는 기본 함수          | `plt.plot(x, y1)`                |
# | `color`                       | 선 색상 지정                         | 초록:`'green'`, 주황:`'orange'`, 보라:`'purple'` |
# | `linestyle`                   | 선의 스타일 설정                     | 실선:`'-'`, 점선:`'--'`, 점-대시선:`'-.'` |
# | **`plt.title()`**             | 차트 제목 설정                       | `plt.title('Three Line Plots: Exponential Functions')` |
# | **`plt.xlabel()` / `plt.ylabel()`** | x축, y축 라벨 설정               | `plt.xlabel('X-axis')`           |
# | **`plt.xlim()` / `plt.ylim()`** | x축, y축 범위 지정                 | `plt.xlim(0,5)`, `plt.ylim(0,150)` |
# | **`plt.legend(loc='upper left')`** | 범례 표시 및 위치 설정            | `plt.legend(loc='upper left')`   |
# | **`plt.grid(True)`**          | 격자 표시                            | `plt.grid(True)`                 |
#
# ---

# %%
import matplotlib.pyplot as plt
import numpy as np

# 데이터 생성
x = np.linspace(0, 5, 100)
y1 = np.exp(x)  # 지수함수
y2 = np.exp(x / 2)  # 지수함수(2로 나눈 값)
y3 = np.exp(x / 3)  # 지수함수(3으로 나눈 값)

# 차트 그리기
plt.figure(figsize=(10, 6))
plt.plot(x, y1, color="green", linestyle="-", label="exp(x)")
plt.plot(x, y2, color="orange", linestyle="--", label="exp(x/2)")
plt.plot(x, y3, color="purple", linestyle="-.", label="exp(x/3)")

# 옵션 설정
plt.title("Three Line Plots: Exponential Functions")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.legend(loc="upper left")
plt.grid(True)

# 표시
plt.show()

# %% [markdown]
# | 스타일      | 설명      | 예시 |
# |------------|-----------|-------|
# | `'-'`      | 실선 (solid)   | `linestyle='-'` |
# | `'--'`     | 점선 (dashed)  | `linestyle='--'` |
# | `'-.'`     | 점-대시선 (dash-dot) | `linestyle='-.'` |
# | `':'`      | 짧은 점선 (dotted)  | `linestyle=':'` |

# %% [markdown]
# ## ② 산점도 (`scatter`)

# %% [markdown]
# **마커(`marker`) 예시:**
#
# | 마커       | 설명      | 예시 |
# |------------|-----------|-------|
# | `'o'`      | 원형 마커      | `marker='o'` |
# | `'x'`      | X 모양 마커     | `marker='x'` |
# | `'s'`      | 사각형 마커     | `marker='s'` |
# | `'D'`      | 다이아몬드 모양 마커 | `marker='D'` |
# | `'^'`      | 삼각형 마커     | `marker='^'` |
#
# ---

# %%
import matplotlib.pyplot as plt
import numpy as np

# 데이터 생성
x = np.random.rand(100)
y = np.random.rand(100)

plt.figure(figsize=(8, 6))
plt.scatter(x, y, color="blue", alpha=0.7, marker="o", label="blue")
plt.scatter(x * 1.1, y * 0.9, color="red", alpha=0.4, marker="o", label="red")
plt.title("Scatter Plot Example")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.legend(loc="upper right")
plt.grid(True)
plt.show()

# %% [markdown]
# ## ③ 막대 차트 (`bar`)

# %%
import matplotlib.pyplot as plt

# 데이터 생성
categories = ["A", "B", "C", "D"]
values = [20, 35, 30, 25]

plt.figure(figsize=(8, 6))
plt.bar(categories, values, color="green")
plt.title("Bar Chart Example")
plt.xlabel("Categories")
plt.ylabel("Values")
plt.grid(axis="y", linestyle="--", alpha=0.7)
plt.show()

# %% [markdown]
# ## ④ 히스토그램 (`hist`)

# %%
import matplotlib.pyplot as plt
import numpy as np

# 데이터 생성
data = np.random.randn(1000)
data
# Out:
# array([ 1.35174384e-01,  9.42528182e-01,  4.75668719e-01,  3.69845434e+00,
#         6.66932400e-01, -5.17982253e-01, -3.10841212e-01, -1.15727687e+00,
#         4.28750145e-01, -7.48811337e-01, -8.71821708e-01,  1.06669998e-01,
#        -1.24233870e+00,  1.28791720e+00,  9.64340676e-02,  1.26908009e+00,
#         1.56268318e+00, -3.08484596e-01,  3.13451103e-02,  1.18312814e+00,
#         2.65233735e-01, -8.88186681e-01,  1.45140340e+00, -6.12700999e-01,
#         4.74011991e-01, -1.72671178e+00,  3.09964717e-01,  1.47634947e+00,
#         1.19570120e-01,  2.31764496e+00, -1.63073101e+00,  1.63755002e-01,
#         1.62674803e-03,  3.57550083e-01,  1.96941379e+00, -1.42209419e+00,
#        -3.01032441e-01, -1.87411395e-01,  1.15970389e+00, -7.07537139e-01,
#         1.16243101e+00,  7.91394435e-01,  6.50848063e-01,  1.03496241e+00,
#         2.05288676e+00,  5.25970251e-01, -1.67894192e+00,  1.54082982e+00,
# ...

# %%
plt.figure(figsize=(8, 6))
plt.hist(data, bins=20, color="red", alpha=0.7)
plt.title("Histogram Example")
plt.xlabel("Values")
plt.ylabel("Frequency")
plt.grid(True)
plt.show()

# %% [markdown]
# ## ⑤ 파이 차트 (`pie`)

# %%
import matplotlib.pyplot as plt

# 데이터 생성
labels = ["Apple", "Banana", "Cherry", "Date"]
sizes = [15, 30, 45, 10]

plt.figure(figsize=(8, 6))
plt.pie(sizes, labels=labels,autopct="%1.0f%%",startangle=90, explode=[0, 0, 0.1, 0]) # labels=labels, autopct="%1.0f%%", startangle=90,)
plt.title("Pie Chart Example")
plt.axis("equal")  # 원형 유지
plt.show()

# %%
## ⑥ 박스 플롯 (`boxplot`)

# %%
import matplotlib.pyplot as plt
import numpy as np

# 데이터 생성
data = [np.random.normal(0, std, 100) for std in range(1, 4)]
len(data)
# Out:
# 3

# %%
plt.figure(figsize=(8, 6))
plt.boxplot(data, labels=["A", "B", "C"])
plt.title("Boxplot Example")
plt.xlabel("Group")
plt.ylabel("Value")
plt.grid(True)
plt.show()
# Out:
# C:\Users\데스크\AppData\Local\Temp\ipykernel_8180\1017349481.py:2: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot(data, labels=["A", "B", "C"])

# %%
## ⑦ 여러개의 차트 (Subplots) 활용 예시

# %%
import matplotlib.pyplot as plt
import numpy as np

# 데이터 생성
x = np.linspace(0, 10, 100)
y1 = np.sin(x)
y2 = np.cos(x)

fig, axes = plt.subplots(2, 2, figsize=(12, 10))

# 라인 차트
axes[0, 0].plot(x, y1, color="blue")
axes[0, 0].set_title("Line Chart (sin)")

# 산점도
axes[0, 1].scatter(x, y2, color="red")
axes[0, 1].set_title("Scatter Plot (cos)")

# 막대 차트
axes[1, 0].bar(["A", "B", "C"], [5, 7, 3], color="green")
axes[1, 0].set_title("Bar Chart")

# 히스토그램
axes[1, 1].hist(np.random.randn(1000), bins=20, color="purple")
axes[1, 1].set_title("Histogram")

# 공통 적용 설정 (for문 이용한 방식 예시)
for ax in axes.flat:
    ax.grid(True)

plt.tight_layout()
plt.show()
